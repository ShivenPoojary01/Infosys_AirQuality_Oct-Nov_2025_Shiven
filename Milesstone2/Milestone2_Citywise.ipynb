# %%
#  Import All Necessary Libraries
import pandas as pd
import numpy as np
import joblib
import matplotlib.pyplot as plt

# Data processing and evaluation
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Time Series Models
from prophet import Prophet
from statsmodels.tsa.arima.model import ARIMA

# Machine Learning Model
import xgboost as xgb

# Deep Learning Model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# Set display options for better visibility
pd.set_option('display.max_columns', None)
print("✅ All libraries imported successfully.")
# Out:
# ✅ All libraries imported successfully.

# %%
# Cell 2 (Revised for CITY-WISE Analysis): Data Cleaning and File Creation

import pandas as pd
import numpy as np

# Load the data using 'latin-1' encoding to prevent errors
df = pd.read_csv('data.csv', encoding='latin-1')


if 'location' in df.columns:
    # Drop any rows where the location name is missing
    unique_locations = df['location'].dropna().unique()
    num_locations = len(unique_locations)

    # Print the results
    print(f"Number of Cities (Locations): {num_locations}")
    print("Names of Cities (Locations):")
    
    # Sort the list alphabetically to make it easy to read
    for location in sorted(unique_locations):
        print(location)
else:
    print("Error: The CSV file does not have a 'location' column.")
# --- 2.1 Cleaning and Type Conversion ---
# The 'location' column will now be our city identifier
pollutant_cols = ['so2', 'no2', 'rspm', 'spm', 'pm2_5']
for col in pollutant_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')
df['date'] = pd.to_datetime(df['date'], errors='coerce')
# Drop columns not needed for this analysis
df = df.drop(columns=['stn_code', 'sampling_date', 'agency', 'type', 'location_monitoring_station'], errors='ignore')
# Ensure we have a date and a city name for every row
df = df.dropna(subset=['date', 'location'])

# --- 2.2 Imputation ---
# Fill missing pollutant values with the overall mean
for col in pollutant_cols:
    df[col] = df[col].fillna(df[col].mean())

# --- 2.3 Feature Engineering: Air Quality Status Column ---
def get_aq_status(rspm):
    if not pd.isna(rspm):
        if rspm <= 50: return 'Good'
        elif rspm <= 100: return 'Satisfactory'
        elif rspm <= 250: return 'Moderate'
        elif rspm <= 350: return 'Poor'
        elif rspm <= 430: return 'Very Poor'
        else: return 'Severe'
    return 'Unknown'
df['AQ_Status'] = df['rspm'].apply(get_aq_status)

# --- 2.4 Aggregation (Per-CITY Model) ---
# KEY CHANGE: We now groupby 'location' (city) instead of 'state'
def get_most_common_status(series):
    # A robust function to find the most common status for a given day
    if not series.mode().empty:
        return series.mode().iloc[0]
    return 'Unknown'

agg_df = df.groupby(['date', 'location']).agg(
    avg_rspm=('rspm', 'mean'),
    avg_so2=('so2', 'mean'),
    avg_no2=('no2', 'mean'),
    Air_Quality_Status=('AQ_Status', get_most_common_status)
).reset_index()

# Round the averages for better readability
agg_df['avg_rspm'] = agg_df['avg_rspm'].round(2)

# --- 2.5 SAVE THE HUMAN-READABLE CSV (Now City-Wise) ---
# This file contains aggregated data for all cities
agg_df.to_csv('human_readable_air_quality_CITYWISE.csv', index=False)
print("✅ Human-readable CITY-WISE file saved: 'human_readable_air_quality_CITYWISE.csv'")

# --- 2.6 PREPARE DATA FOR A SINGLE CITY MODEL ---
# KEY CHANGE: Define and filter by the city you want to predict
CITY_TO_PREDICT = 'Mumbai'
ts_city_df = agg_df[agg_df['location'] == CITY_TO_PREDICT]

# Create the final DataFrame with 'ds' and 'y' columns for the models
final_ts_df = ts_city_df[['date', 'avg_rspm']].rename(
    columns={'date': 'ds', 'avg_rspm': 'y'}
)

# Save the model-ready file for the specific city
final_ts_df.to_csv(f'clean_air_quality_{CITY_TO_PREDICT}.csv', index=False)
print(f"\n✅ Model-ready file for {CITY_TO_PREDICT} saved: 'clean_air_quality_{CITY_TO_PREDICT}.csv'")

# --- 2.7 Split the data for the next steps ---
TEST_SIZE = 30
train_df = final_ts_df.iloc[:-TEST_SIZE].copy()
test_df = final_ts_df.iloc[-TEST_SIZE:].copy()
y_actual = test_df['y'].values
model_results = {} # Reset the results dictionary for the new city
print(f"\nData for {CITY_TO_PREDICT} is ready for model training.")
# Out:
# C:\Users\LeNoVo\AppData\Local\Temp\ipykernel_9324\3530845159.py:7: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data.csv', encoding='latin-1')
# Number of Cities (Locations): 304
# Names of Cities (Locations):
# ANKLESHWAR
# Agra
# Ahmedabad
# Aizawl
# Akola
# Alappuzha
# Allahabad
# Alwar
# Amlai
# Amona
# Amravati
# Amritsar
# Ananthapur
# Angul
# Ankleshwar
# Anklesvar
# Anpara
# Asansol
# Assanora
# Aurangabad
# Aurangabad (MS)
# Baddi
# Badlapur
# Balasore
# Bangalore
# Bareilly
# Baroda
# Barrackpore
# Baruipur
# Bathinda
# Belgaum
# Berhampur
# Bharuch
# Bhilai
# Bhilai Nagar
# Bhopal
# Bhubaneshwar
# Bhubaneswar
# Bhuj
# Bicholim
# Bidar
# Bijapur
# Bilaspur
# Bombay
# Bongaigaon
# Byrnihat
# Calcutta
# Champhai
# Chandarpur
# Chandigarh
# Chandrapur
# Chennai
# Chhindwara
# Chitradurga
# Chittoor
# Chittorgarh
# Cochin
# Codli
# Coimbatore
# Cuddalore
# Cuncolim
# Curchorem
# Cuttack
# DANKUNI
# Daman
# Daman Diu & Nagar
# Damtal
# Daranga
# Davangere
# Dawki
# Dehradoon
# Dehradun
# Delhi
# Dera Baba
# Dera Bassi
# Dewas
# Dhanbad
# Dharamshala
# Dharuhera
# Dharwad
# Dibrugarh
# Dimapur
# Dombivli
# Domlur
# Durgapur
# Durgapur (WB)
# Eluru
# Faridabad
# Faridkot
# Firozabad
# Gajraula
# Gajroula
# Gangtok
# Ghaziabad
# Gobindgarh
# Golaghat
# Gorakhpur
# Greater Mumbai
# Gulbarga
# Guntur
# Guwahati
# Gwalior
# HALDIA
# Hailakandi
# Haldia
# Haldwani
# Haridwar
# Hassan
# Hisar
# Honda
# Hoshiarpur
# Howrah
# Hubli
# Hubli-Dharwad
# Hyderabad
# Imphal
# Indore
# Itanagar
# Jabalpur
# Jaipur
# Jalandhar
# Jalgaon
# Jalna
# Jammu
# Jamnagar
# Jamshedpur
# Jhansi
# Jharia
# Jodhpur
# Kadapa
# Kakinada
# Kala Amb
# Kalinga Nagar
# Kalyani
# Kanpur
# Karaikal
# Karimnagar
# Kashipur
# Keonjhar
# Khadoli
# Khajuraho
# Khammam
# Khanna
# Khliehriat
# Khurja
# Kochi
# Kohima
# Kolar
# Kolasib
# Kolhapur
# Kolkata
# Kollam
# Konark
# Korba
# Kota
# Kothur
# Kottayam
# Kotttayam
# Kozhikode
# Kundaim
# Kurnool
# Lakhimpur
# Latur
# Lote
# Lucknow
# Ludhiana
# Lunglei
# MALDAH
# MORBI
# Madras
# Madurai
# Mahad
# Malappuram
# Manali
# Mandya
# Mangalore
# Mapusa
# Margao
# Margherita
# Mathura
# Meerut
# Mettur
# Moradabad
# Mormugao
# Mumbai
# Mysore
# Nagaon
# Nagda
# Nagpur
# Nahan
# Naharlagun
# Nalagarh
# Nalbari
# Nalco
# Nalgonda
# Nanded
# Nashik
# Navi Mumbai
# Naya Nangal
# Nellore
# Nizamabad
# Noida
# Noida, Ghaziabad
# Nongstoin
# Ongole
# Palakkad
# Panaji
# Panjim
# Paonta Sahib
# Paradeep
# Parwanoo
# Patancheru
# Pathanamthitta
# Patiala
# Patna
# Pithampur
# Ponda
# Pondicherry
# Pondichery
# Pune
# Puri
# Rai Bareilly
# Raichur
# Raipur
# Rajahmundry
# Rajkot
# Ramagundam
# Ranchi
# Ranebennur
# Raniganj
# Rayagada
# Renusagar
# Rishikesh
# Roha
# Rourkela
# Rudrapur
# SANAND
# SILIGURI
# Sagar
# Saharanpur
# Salem
# Sambalpur
# Sangareddy
# Sangli
# Sangrur
# Sanguem
# Sankrail
# Saraikela Kharsawan
# Sarigam
# Satna
# Shillong
# Shimla
# Shimoga
# Sibsagar
# Silchar
# Silcher
# Silvassa
# Sindri
# Singrauli
# Sivasagar
# Solapur
# South Suburban
# Srikakulam
# Sunder Nagar
# Surat
# Talcher
# Tarapur
# Tezpur
# Thane
# Thiruvananthapuram
# Thissur
# Thoothukudi
# Tilamol
# Tinsukia
# Tirupati
# Trichy
# Trivandrum
# Trivendrum
# Tumkur
# Tura
# Turicorin
# Tuticorin
# ULUBERIA
# Udaipur
# Ujjain
# Ulhasnagar
# Umsning
# Una
# Unnao
# Usgao
# VAPI
# Vadodara
# Vapi
# Varanasi
# Vasco
# Vijayawada
# Visakhapatnam
# Vishakhapatnam
# Vizianagaram
# Warangal
# Wayanad
# West Singhbhum
# Yamuna Nagar
# Yamunanagar
# ✅ Human-readable CITY-WISE file saved: 'human_readable_air_quality_CITYWISE.csv'
#
# ✅ Model-ready file for Mumbai saved: 'clean_air_quality_Mumbai.csv'
#
# Data for Mumbai is ready for model training.

# %%
# Train and Evaluate ARIMA and Prophet Models

# ARIMA Model ---
print("\n--- Training ARIMA Model ---")
arima_train_series = train_df.set_index('ds')['y']
try:
    m_arima = ARIMA(arima_train_series, order=(5, 1, 0)).fit()
    y_pred_arima = m_arima.forecast(steps=TEST_SIZE).values
    mae_arima = mean_absolute_error(y_actual, y_pred_arima)
    rmse_arima = np.sqrt(mean_squared_error(y_actual, y_pred_arima))
    model_results['ARIMA'] = {'MAE': mae_arima, 'RMSE': rmse_arima, 'Model': m_arima}
    print(f"✅ ARIMA - MAE: {mae_arima:.2f}, RMSE: {rmse_arima:.2f}")
except Exception as e:
    print(f"❌ ARIMA failed: {e}")
    model_results['ARIMA'] = {'MAE': np.inf, 'RMSE': np.inf, 'Model': None}

# Prophet Model ---
print("\n--- Training Prophet Model ---")
m_prophet = Prophet(daily_seasonality=True, weekly_seasonality=True)
m_prophet.fit(train_df)
y_pred_prophet = m_prophet.predict(test_df[['ds']])['yhat'].values
mae_prophet = mean_absolute_error(y_actual, y_pred_prophet)
rmse_prophet = np.sqrt(mean_squared_error(y_actual, y_pred_prophet))
model_results['Prophet'] = {'MAE': mae_prophet, 'RMSE': rmse_prophet, 'Model': m_prophet}
print(f"✅ Prophet - MAE: {mae_prophet:.2f}, RMSE: {rmse_prophet:.2f}")
# Out:
# --- Training ARIMA Model ---
# C:\Users\LeNoVo\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\LeNoVo\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\LeNoVo\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\LeNoVo\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\LeNoVo\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
# ✅ ARIMA - MAE: 39.41, RMSE: 47.60
#
# --- Training Prophet Model ---
# 00:31:24 - cmdstanpy - INFO - Chain [1] start processing
# 00:31:25 - cmdstanpy - INFO - Chain [1] done processing
# ✅ Prophet - MAE: 53.82, RMSE: 66.59

# %%
# Train and Evaluate XGBoost Model

print("\n--- Training XGBoost Model ---")

# Feature Engineering ---
def create_features(df_in):
    df_out = df_in.copy()
    df_out['dayofweek'] = df_out['ds'].dt.dayofweek
    df_out['month'] = df_out['ds'].dt.month
    df_out['year'] = df_out['ds'].dt.year
    df_out['lag_7'] = df_out['y'].shift(7)
    return df_out.dropna()

full_df_features = create_features(final_ts_df)
train_features = full_df_features[full_df_features['ds'].isin(train_df['ds'])]
test_features = full_df_features[full_df_features['ds'].isin(test_df['ds'])]
FEATURES = ['dayofweek', 'month', 'year', 'lag_7']
X_train, y_train = train_features[FEATURES], train_features['y']
X_test, y_test = test_features[FEATURES], test_features['y']

# Training and Evaluation ---
m_xgb = xgb.XGBRegressor(objective='reg:squarederror', n_estimators=100, random_state=42)
m_xgb.fit(X_train, y_train)
y_pred_xgb = m_xgb.predict(X_test)
mae_xgb = mean_absolute_error(y_test, y_pred_xgb)
rmse_xgb = np.sqrt(mean_squared_error(y_test, y_pred_xgb))
model_results['XGBoost'] = {'MAE': mae_xgb, 'RMSE': rmse_xgb, 'Model': m_xgb}
print(f"✅ XGBoost - MAE: {mae_xgb:.2f}, RMSE: {rmse_xgb:.2f}")
# Out:
# --- Training XGBoost Model ---
# ✅ XGBoost - MAE: 50.98, RMSE: 59.21

# %%
#  Train and Evaluate LSTM Model

print("\n--- Training LSTM Model (this will show progress) ---")
from tensorflow.keras.layers import Input

# Data Preparation (with Corrected Sequence Function) 
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(final_ts_df[['y']])
train_data = scaled_data[:-TEST_SIZE]
test_data = scaled_data[len(train_data) - 60:]

# Function to create sequences of data
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    # The "- 1" was removed from the end of the range to create the correct number of samples
    for i in range(len(dataset) - time_step):
        a = dataset[i:(i + time_step), 0]
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

time_step = 60
X_train_lstm, y_train_lstm = create_dataset(train_data, time_step)
X_test_lstm, y_test_lstm = create_dataset(test_data, time_step)
X_train_lstm = X_train_lstm.reshape(X_train_lstm.shape[0], X_train_lstm.shape[1], 1)
X_test_lstm = X_test_lstm.reshape(X_test_lstm.shape[0], X_test_lstm.shape[1], 1)

#  Build and Train Model ---
m_lstm = Sequential([
    Input(shape=(time_step, 1)),
    LSTM(50, return_sequences=True),
    LSTM(50),
    Dense(1)
])
m_lstm.compile(optimizer='adam', loss='mean_squared_error')
m_lstm.fit(X_train_lstm, y_train_lstm, validation_data=(X_test_lstm, y_test_lstm), 
           epochs=20, batch_size=64, verbose=1)

# Prediction and Evaluation ---
y_pred_lstm_scaled = m_lstm.predict(X_test_lstm)
y_pred_lstm = scaler.inverse_transform(y_pred_lstm_scaled)

mae_lstm = mean_absolute_error(y_actual, y_pred_lstm)
rmse_lstm = np.sqrt(mean_squared_error(y_actual, y_pred_lstm))
model_results['LSTM'] = {'MAE': mae_lstm, 'RMSE': rmse_lstm, 'Model': m_lstm}
print(f"✅ LSTM - MAE: {mae_lstm:.2f}, RMSE: {rmse_lstm:.2f}")
# Out:
# --- Training LSTM Model (this will show progress) ---
# Epoch 1/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 13s 162ms/step - loss: 0.0089 - val_loss: 0.0051
# Epoch 2/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - loss: 0.0072 - val_loss: 0.0065
# Epoch 3/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - loss: 0.0070 - val_loss: 0.0061
# Epoch 4/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - loss: 0.0071 - val_loss: 0.0049
# Epoch 5/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - loss: 0.0072 - val_loss: 0.0057
# Epoch 6/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - loss: 0.0070 - val_loss: 0.0054
# Epoch 7/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - loss: 0.0070 - val_loss: 0.0053
# Epoch 8/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 118ms/step - loss: 0.0069 - val_loss: 0.0053
# Epoch 9/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - loss: 0.0070 - val_loss: 0.0061
# Epoch 10/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.0070 - val_loss: 0.0050
# Epoch 11/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.0070 - val_loss: 0.0059
# Epoch 12/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 0.0069 - val_loss: 0.0049
# Epoch 13/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 121ms/step - loss: 0.0069 - val_loss: 0.0059
# Epoch 14/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - loss: 0.0068 - val_loss: 0.0050
# Epoch 15/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - loss: 0.0068 - val_loss: 0.0052
# Epoch 16/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - loss: 0.0067 - val_loss: 0.0053
# Epoch 17/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - loss: 0.0068 - val_loss: 0.0060
# Epoch 18/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 119ms/step - loss: 0.0067 - val_loss: 0.0049
# Epoch 19/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 119ms/step - loss: 0.0067 - val_loss: 0.0054
# Epoch 20/20
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - loss: 0.0067 - val_loss: 0.0054
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ✅ LSTM - MAE: 38.21, RMSE: 47.34

# %%
# Final Model Comparison and Saving

import matplotlib.pyplot as plt
import pandas as pd

print("\n--- Final Model Performance Summary ---")

# Create a DataFrame for easy comparison and sort by MAE
# Ensure 'Model' column is dropped if it exists from previous runs
performance_df = pd.DataFrame(model_results).T
if 'Model' in performance_df.columns:
    performance_df = performance_df.drop(columns='Model')

performance_df = performance_df.sort_values('MAE')
print(performance_df)

# Create a bar chart to compare model errors
fig, ax = plt.subplots(figsize=(12, 7))
performance_df.plot(kind='bar', ax=ax)

# Set chart titles and labels
ax.set_title('Model Performance Comparison', fontsize=16)
ax.set_ylabel('Error Value (lower is better)', fontsize=12)
ax.set_xlabel('Forecasting Model', fontsize=12)
ax.set_xticklabels(performance_df.index, rotation=45, ha='right')
ax.grid(axis='y', linestyle='--', alpha=0.7)
ax.legend(title='Error Metric')

# Display the plot
plt.tight_layout()
plt.show()


best_model_name = performance_df.index[0]
best_model_obj = model_results[best_model_name]['Model']

print(f"\n🎉 Best performing model based on MAE is '{best_model_name}'.")

# --- Save the best-performing model for inference ---
if best_model_name == 'LSTM':
    try:
        # Keras native saving format is preferred for neural networks
        best_model_obj.save('best_air_quality_model.h5')
        print("✅ Model saved for inference as 'best_air_quality_model.h5'.")
    except Exception as e:
        print(f"\nCould not save Keras model directly. Error: {e}")
else:
    # Use joblib for other models
    joblib.dump(best_model_obj, 'best_air_quality_model.joblib')
    print("✅ Model saved for inference as 'best_air_quality_model.joblib'.")
# Out:
# --- Final Model Performance Summary ---
#                MAE       RMSE
# LSTM     38.210125  47.341114
# ARIMA    39.406419  47.595157
# XGBoost  50.982789  59.205177
# Prophet  53.823852  66.592127
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 🎉 Best performing model based on MAE is 'LSTM'.
# ✅ Model saved for inference as 'best_air_quality_model.h5'.
